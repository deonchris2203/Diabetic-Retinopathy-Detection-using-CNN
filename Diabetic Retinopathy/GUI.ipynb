# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# %%
#BUTTON PROP  
b1 = Button(top,text = "Import Images",activeforeground = "red",activebackground = "pink",pady=10, height=1, width=15)  
  
b2 = Button(top, text = "Process", activeforeground = "blue",activebackground = "pink",pady=10, height=1, width=15)  
  
b3 = Button(top, text = "Clear", activeforeground = "green",activebackground = "pink",pady = 10, height=1, width=15)  
  
b4 = Button(top, text = "Show Result", activeforeground = "yellow",activebackground = "pink",pady = 10, height=1, width=15)  


#BUTTON PACKING 
b1.pack()   
b2.pack()  
b3.pack()  
b4.pack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12448/1818291142.py in <module>
#       1 #BUTTON PROP
# ----> 2 b1 = Button(top,text = "Import Images",activeforeground = "red",activebackground = "pink",pady=10, height=1, width=15)
#       3
#       4 b2 = Button(top, text = "Process", activeforeground = "blue",activebackground = "pink",pady=10, height=1, width=15)
#       5
#
# NameError: name 'Button' is not defined

# %%
from tkinter import *
from tkinter import messagebox
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# %%
root = Tk()

# %%
#THE MAIN WINDOW

root.title("Deon Chris")
window_width = 500
window_height = 300

# get the screen dimension
screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()

# find the center point
center_x = int(screen_width/2 - window_width / 2)
center_y = int(screen_height/2 - window_height / 2)

# set the position of the window to the center of the screen
root.geometry(f'{window_width}x{window_height}+{center_x}+{center_y}')

# NO RESIZE
root.resizable(False, False)
# Out:
# ''

# %% [markdown]
# # def

# %%
frame = Frame(root)
frame.pack()

# %%
bottomframe = Frame(root)
bottomframe.pack( side = BOTTOM )

# %%
topframe = Frame(root, bg="black")
topframe.pack(side = TOP)

# %%
top_left = Frame(topframe)
top_left.pack(side = LEFT)

# %%
redbutton = Button(topframe, text="Red", fg="red")
redbutton.pack( side = LEFT)

greenbutton = Button(bottomframe, text="Brown", fg="brown")
greenbutton.pack( side = LEFT )

bluebutton = Button(top_left, text="Blue", fg="blue")
bluebutton.pack( side = LEFT )

blackbutton = Button(bottomframe, text="Black", fg="black")
blackbutton.pack( side = BOTTOM)

# %%
root.mainloop()

# %%
# Import Module
from tkinter import *
 
# Create Tkinter Object
root = Tk()
 
# Set Geometry
root.geometry("400x400")
 
# Frame 1
frame1 = Frame(root,bg="black")
frame1.pack()
 
# Frame 2
frame2 = Frame(frame1,bg="white")
frame2.pack(pady=20,padx=20)
 
# Execute Tkinter
root.mainloop()

# %%
import tkinter as tk

def on_button_click():
    label.config(text="Button Clicked!")

# Create the main window
root = tk.Tk()
root.title("Nested PanedWindow Example")

# Create the main PanedWindow
main_paned_window = tk.PanedWindow(root, orient=tk.VERTICAL, sashrelief=tk.FLAT)
main_paned_window.pack(expand=True, fill=tk.BOTH)

# Add the top panel to the main PanedWindow
top_pane = tk.Frame(main_paned_window, bg="lightblue", padx=10, pady=10)
main_paned_window.add(top_pane, minsize=70)  # 70% of the vertical space

# Create a nested PanedWindow for the top panel
nested_paned_window = tk.PanedWindow(top_pane, orient=tk.HORIZONTAL, sashrelief=tk.FLAT)
nested_paned_window.pack(expand=True, fill=tk.BOTH)

# Add the left sub-panel to the nested PanedWindow
left_subpane = tk.Frame(nested_paned_window, bg="lightcoral", padx=5, pady=5)
nested_paned_window.add(left_subpane, minsize=40)  # 40% of the horizontal space

# Add widgets to the left sub-panel
label_left = tk.Label(left_subpane, text="Left Sub-Panel", font=("Helvetica", 12))
label_left.pack(pady=5)

# Add the right sub-panel to the nested PanedWindow
right_subpane = tk.Frame(nested_paned_window, bg="lightgreen", padx=5, pady=5)
nested_paned_window.add(right_subpane, minsize=60)  # 60% of the horizontal space

# Add widgets to the right sub-panel
label_right = tk.Label(right_subpane, text="Right Sub-Panel", font=("Helvetica", 12))
label_right.pack(pady=5)

# Add the bottom panel to the main PanedWindow
bottom_pane = tk.Frame(main_paned_window, bg="lightyellow", padx=10, pady=10)
main_paned_window.add(bottom_pane, minsize=30)  # 30% of the vertical space

# Add widgets to the bottom panel
entry = tk.Entry(bottom_pane, width=30)
entry.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk

def on_button_click():
    label.config(text="Button Clicked!")

def on_resize(event):
    # Dynamically adjust the sizes of the panes when the window is resized
    main_paned_window.update()

# Create the main window
root = tk.Tk()
root.title("Dynamic Resizing Example")

# Create the main PanedWindow
main_paned_window = tk.PanedWindow(root, orient=tk.VERTICAL, sashrelief=tk.FLAT)
main_paned_window.pack(expand=True, fill=tk.BOTH)

# Add the top panel to the main PanedWindow
top_pane = tk.Frame(main_paned_window, bg="lightblue", padx=10, pady=10)
main_paned_window.add(top_pane, minsize=70)  # 70% of the vertical space

# Create a nested PanedWindow for the top panel
nested_paned_window = tk.PanedWindow(top_pane, orient=tk.HORIZONTAL, sashrelief=tk.FLAT)
nested_paned_window.pack(expand=True, fill=tk.BOTH)

# Add the left sub-panel to the nested PanedWindow
left_subpane = tk.Frame(nested_paned_window, bg="lightcoral", padx=5, pady=5)
nested_paned_window.add(left_subpane, minsize=40)  # 40% of the horizontal space

# Add widgets to the left sub-panel
label_left = tk.Label(left_subpane, text="Left Sub-Panel", font=("Helvetica", 12))
label_left.pack(pady=5)

# Add the right sub-panel to the nested PanedWindow
right_subpane = tk.Frame(nested_paned_window, bg="lightgreen", padx=5, pady=5)
nested_paned_window.add(right_subpane, minsize=60)  # 60% of the horizontal space

# Add widgets to the right sub-panel
label_right = tk.Label(right_subpane, text="Right Sub-Panel", font=("Helvetica", 12))
label_right.pack(pady=5)

# Add the bottom panel to the main PanedWindow
bottom_pane = tk.Frame(main_paned_window, bg="lightyellow", padx=10, pady=10)
main_paned_window.add(bottom_pane, minsize=30)  # 30% of the vertical space

# Add widgets to the bottom panel
entry = tk.Entry(bottom_pane, width=30)
entry.pack(pady=10)

# Bind the resize event to the on_resize function
root.bind("<Configure>", on_resize)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk

def on_button_click(button_number):
    label.config(text=f"Button {button_number} Clicked!")

# Create the main window
root = tk.Tk()
root.title("Four Buttons Example")

# Set the window size and make it non-resizable
root.geometry("900x600")
root.resizable(False, False)

# Create a frame to hold the buttons on the left side
button_frame1 = tk.Frame(root, width=200, bg="lightgray")
button_frame1.pack(side=tk.LEFT, fill=tk.Y)

button_frame2 = tk.Frame(root, width=200, bg="lightgray")
button_frame2.pack(side=tk.LEFT, fill=tk.Y)

button_frame3 = tk.Frame(root, width=200, bg="lightgray")
button_frame3.pack(side=tk.LEFT, fill=tk.Y)

button_frame4 = tk.Frame(root, width=200, bg="lightgray")
button_frame4.pack(side=tk.LEFT, fill=tk.Y)

# Create individual buttons and add them to their respective frames
button1 = tk.Button(button_frame1, text="Button 1", width=15, command=lambda: on_button_click(1))
button1.pack(pady=10)

button2 = tk.Button(button_frame2, text="Button 2", width=15, command=lambda: on_button_click(2))
button2.pack(pady=10)

button3 = tk.Button(button_frame3, text="Button 3", width=15, command=lambda: on_button_click(3))
button3.pack(pady=10)

button4 = tk.Button(button_frame4, text="Button 4", width=15, command=lambda: on_button_click(4))
button4.pack(pady=10)

# Create a label on the right side
label = tk.Label(root, text="Hello, Tkinter!", font=("Helvetica", 16))
label.pack(side=tk.RIGHT, padx=20)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk

def on_button_click(button_number):
    label.config(text=f"Button {button_number} Clicked!")

# Create the main window
root = tk.Tk()
root.title("Four Buttons Example")

# Set the window size and make it non-resizable
root.geometry("900x600")
root.resizable(False, False)

# Create a frame to hold the buttons on the left side
button_frame = tk.Frame(root, width=400, bg="lightgray")
button_frame.pack(side=tk.LEFT, fill=tk.Y)

# Create individual buttons and add them to the frame
button1 = tk.Button(button_frame, text="Button 1", width=15, command=lambda: on_button_click(1))
button1.pack(pady=20)

button2 = tk.Button(button_frame, text="Button 2", width=15, command=lambda: on_button_click(2))
button2.pack(pady=20)

button3 = tk.Button(button_frame, text="Button 3", width=15, command=lambda: on_button_click(3))
button3.pack(pady=20)

button4 = tk.Button(button_frame, text="Button 4", width=15, command=lambda: on_button_click(4))
button4.pack(pady=20)

# Create a label on the right side
label = tk.Label(root, text="Hello, Tkinter!", font=("Helvetica", 16))
label.pack(side=tk.RIGHT, padx=20)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk  # Make sure to install the Pillow library

def on_button_click(button_number):
    label.config(text=f"Button {button_number} Clicked!")

# Create the main window
root = tk.Tk()
root.title("Four Buttons Example")

# Set the window size and make it non-resizable
root.geometry("900x600")
root.resizable(False, False)

# Create a frame to hold the buttons on the left side
button_frame = tk.Frame(root, width=300, bg="lightgray")
button_frame.pack(side=tk.LEFT, fill=tk.Y)

# Create individual buttons and add them to the frame
button1 = tk.Button(button_frame, text="Button 1", width=15, command=lambda: on_button_click(1))
button1.pack(pady=10)

button2 = tk.Button(button_frame, text="Button 2", width=15, command=lambda: on_button_click(2))
button2.pack(pady=10)

button3 = tk.Button(button_frame, text="Button 3", width=15, command=lambda: on_button_click(3))
button3.pack(pady=10)

button4 = tk.Button(button_frame, text="Button 4", width=15, command=lambda: on_button_click(4))
button4.pack(pady=10)

# Create a frame to hold labels on the right side
label_frame = tk.Frame(root, bg="lightyellow")
label_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True, padx=20)

# Load images and create PhotoImage objects
image1 = Image.open("C:/Users/dfern/Diabetic Retinopathy/797140.png")  # Replace with the actual path to your image
image1 = image1.resize((200, 200), Image.ANTIALIAS)
photo1 = ImageTk.PhotoImage(image1)

image2 = Image.open("C:/Users/dfern/Diabetic Retinopathy/797140.png")  # Replace with the actual path to your image
image2 = image2.resize((200, 200), Image.ANTIALIAS)
photo2 = ImageTk.PhotoImage(image2)

# Create labels and display images
label_image1 = tk.Label(label_frame, image=photo1)
label_image1.pack(pady=10)

label_image2 = tk.Label(label_frame, image=photo2)
label_image2.pack(pady=10)

# Create a label on the right side
label = tk.Label(label_frame, text="Hello, Tkinter!", font=("Helvetica", 16))
label.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12448/2808554405.py in <module>
#      44
#      45 # Create labels and display images
# ---> 46 label_image1 = tk.Label(label_frame, image=photo1)
#      47 label_image1.pack(pady=10)
#      48
#
# ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    3175
#    3176         """
# -> 3177         Widget.__init__(self, master, 'label', cnf, kw)
#    3178
#    3179
#
# ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2599         for k, v in classes:
#    2600             del cnf[k]
# -> 2601         self.tk.call(
#    2602             (widgetName, self._w) + extra + self._options(cnf))
#    2603         for k, v in classes:
#
# TclError: image "pyimage17" doesn't exist

# %%
import tkinter as tk
from PIL import Image, ImageTk

def on_button_click(button_number):
    if button_number == 1:
        # Change the image on the first label after clicking Button 1
        updated_image = Image.open("path/to/your/updated_image.png")  # Replace with the actual path to your image
        updated_image = updated_image.resize((200, 200), Image.ANTIALIAS)
        updated_photo = ImageTk.PhotoImage(updated_image)
        label_image1.config(image=updated_photo)
        label_image1.image = updated_photo
        label.config(text="Button 1 Clicked!")

# Create the main window
root = tk.Tk()
root.title("Four Buttons Example")

# Set the window size and make it non-resizable
root.geometry("900x600")
root.resizable(False, False)

# Create a frame to hold the buttons on the left side
button_frame = tk.Frame(root, width=300, bg="lightgray")
button_frame.pack(side=tk.LEFT, fill=tk.Y)

# Create individual buttons and add them to the frame
button1 = tk.Button(button_frame, text="Button 1", width=15, command=lambda: on_button_click(1))
button1.pack(pady=10)

button2 = tk.Button(button_frame, text="Button 2", width=15, command=lambda: on_button_click(2))
button2.pack(pady=10)

button3 = tk.Button(button_frame, text="Button 3", width=15, command=lambda: on_button_click(3))
button3.pack(pady=10)

button4 = tk.Button(button_frame, text="Button 4", width=15, command=lambda: on_button_click(4))
button4.pack(pady=10)

# Create a frame to hold labels on the right side
label_frame = tk.Frame(root, bg="lightyellow")
label_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True, padx=20)

# Load initial image for the first label
initial_image = Image.open("path/to/your/initial_image.png")  # Replace with the actual path to your image
initial_image = initial_image.resize((200, 200), Image.ANTIALIAS)
initial_photo = ImageTk.PhotoImage(initial_image)

# Create labels and display images
label_image1 = tk.Label(label_frame, image=initial_photo)
label_imag
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12448/4074396708.py in <module>
#      42
#      43 # Load initial image for the first label
# ---> 44 initial_image = Image.open("path/to/your/initial_image.png")  # Replace with the actual path to your image
#      45 initial_image = initial_image.resize((200, 200), Image.ANTIALIAS)
#      46 initial_photo = ImageTk.PhotoImage(initial_image)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2951
#    2952     if filename:
# -> 2953         fp = builtins.open(filename, "rb")
#    2954         exclusive_fp = True
#    2955
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/your/initial_image.png'

# %%
from tkinter import *

# %%
root = Tk()
root.title("hello")
root.geometry("900x550")
# Out:
# ''

# %%
def on_button_click(button_number):
    print(f"Button {button_number} Clicked!")

# %%
#panels
panel_1 = PanedWindow(bd=4, relief='raised', bg='lightblue')
panel_1.pack(fill=BOTH, expand=1)

# %%
# Adding buttons to the left panel
button1 = Button(panel_1, text="Button 1", command=lambda: on_button_click(1))
button1.pack(fill=X)

button2 = Button(panel_1, text="Button 2", command=lambda: on_button_click(2))
button2.pack(fill=X)

button3 = Button(panel_1, text="Button 3", command=lambda: on_button_click(3))
button3.pack(fill=X)

button4 = Button(panel_1, text="Button 4", command=lambda: on_button_click(4))
button4.pack(fill=X)

# %%
left_label = Label(panel_1, text= "Left Panel")
panel_1.add(button1)
panel_1.add(button2)
panel_1.add(button3)
panel_1.add(button4)

# %%
#create second panel
panel_2 = PanedWindow(panel_1, orient=VERTICAL, bd=4, relief="raised", bg='red')
panel_1.add(panel_2)

# %%
top = Label(panel_2, text="Top Panel")
panel_2.add(top, minsize=450)

bottom = Label(panel_2,text="Bottom Panel")
panel_2.add(bottom, minsize=150)

# %%
root.mainloop()
# Out:
# Button 1 Clicked!
# Button 2 Clicked!
# Button 3 Clicked!
# Button 4 Clicked!
# Button 2 Clicked!
# Button 1 Clicked!
# Button 3 Clicked!
# Button 4 Clicked!

# %%
from tkinter import *
from tkinter import filedialog
from PIL import Image, ImageTk

def on_button_click(button_number):
    print(f"Button {button_number} Clicked!")
    
def on_button_click(button_number):
    if button_number == 1:
        file_path = filedialog.askopenfilename(title="Select Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
        if file_path:
            # Load the selected image
            selected_image = Image.open(file_path)
            selected_image = selected_image.resize((300, 100), Image.ANTIALIAS)
            selected_photo = ImageTk.PhotoImage(selected_image)

            # Update the image in the top panel label
            label_image1.config(image=selected_photo)
            label_image1.image = selected_photo

            print(f"Image selected: {file_path}")

root = Tk()
root.title("hello")
root.geometry("900x650")

# panels
panel_1 = PanedWindow(bd=4, relief='raised', bg='lightblue')
panel_1.pack(fill=BOTH, expand=1)

# Create a frame to hold buttons and label in panel_1
button_frame = Frame(panel_1, bg='lightblue')

# Adding buttons to the left panel
button1 = Button(button_frame, text="Select Image", command=lambda: on_button_click(1), width=15, height=3)
button1.pack(fill=X, pady=5)

button2 = Button(button_frame, text="Start Process", command=lambda: on_button_click(2),width=15, height=3)
button2.pack(fill=X, pady=5)

button3 = Button(button_frame, text="Clear", command=lambda: on_button_click(3), width=15, height=3)
button3.pack(fill=X, pady=5)

button4 = Button(button_frame, text="Exit", command=lambda: on_button_click(4), width=15, height=3)
button4.pack(fill=X, pady=5)

left_label = Label(button_frame, text="Left Panel")
left_label.pack()

# Add the button_frame to panel_1
panel_1.add(button_frame, minsize=200)

# create second panel
panel_2 = PanedWindow(panel_1, orient=VERTICAL, bd=4, relief="raised", bg='red')
panel_1.add(panel_2)

top = Label(panel_2, text="Top Panel")
panel_2.add(top, minsize=450)

bottom = Label(panel_2, text="Bottom Panel")
panel_2.add(bottom, minsize=150)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dfern\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\dfern\AppData\Local\Temp/ipykernel_15436/1237508419.py", line 35, in <lambda>
#     button1 = Button(button_frame, text="Select Image", command=lambda: on_button_click(1), width=15, height=3)
#   File "C:\Users\dfern\AppData\Local\Temp/ipykernel_15436/1237508419.py", line 18, in on_button_click
#     label_image1.config(image=selected_photo)
# NameError: name 'label_image1' is not defined

# %%
from tkinter import *
from tkinter import filedialog
from PIL import Image, ImageTk

def on_button_click(button_number):
    if button_number in (1, 2):
        file_path = filedialog.askopenfilename(title="Select Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
        if file_path:
            # Load the selected image
            selected_image = Image.open(file_path)
            selected_image = selected_image.resize((200, 200), Image.ANTIALIAS)
            selected_photo = ImageTk.PhotoImage(selected_image)

            # Update the corresponding image in the top panel
            if button_number == 1:
                label_image1.config(image=selected_photo)
                label_image1.image = selected_photo
                print(f"Image 1 selected: {file_path}")
            elif button_number == 2:
                label_image2.config(image=selected_photo)
                label_image2.image = selected_photo
                print(f"Image 2 selected: {file_path}")

root = Tk()
root.title("Image Comparison")
root.geometry("900x650")

# Panels
panel_1 = PanedWindow(bd=4, relief='raised', bg='lightblue')
panel_1.pack(fill=BOTH, expand=1)

# Create a frame to hold buttons and labels in panel_1
button_frame = Frame(panel_1, bg='lightblue')

# Adding buttons to the left panel
button1 = Button(button_frame, text="Select Image 1", command=lambda: on_button_click(1), width=15, height=3)
button1.pack(fill=X, pady=5)

button2 = Button(button_frame, text="Select Image 2", command=lambda: on_button_click(2), width=15, height=3)
button2.pack(fill=X, pady=5)

button3 = Button(button_frame, text="Clear", command=lambda: on_button_click(3), width=15, height=3)
button3.pack(fill=X, pady=5)

button4 = Button(button_frame, text="Exit", command=lambda: on_button_click(4), width=15, height=3)
button4.pack(fill=X, pady=5)

left_label = Label(button_frame, text="Left Panel")
left_label.pack()

# Create a frame for image display
image_display_frame = Frame(root)
image_display_frame.pack(side=TOP)

# Create label_image1 and label_image2 before using them
label_image1 = Label(image_display_frame, text="Image 1 Display")
label_image1.pack(side=LEFT)

label_image2 = Label(image_display_frame, text="Image 2 Display")
label_image2.pack(side=LEFT)

# Add the button_frame to panel_1
panel_1.add(button_frame, minsize=200)

# Create second panel
panel_2 = PanedWindow(panel_1, orient=VERTICAL, bd=4, relief="raised", bg='red')
panel_1.add(panel_2)

bottom = Label(panel_2, text="Bottom Panel")
panel_2.add(bottom, minsize=150)

root.mainloop()
# Out:
# Image 1 selected: C:/Users/dfern/OneDrive/Pictures/Camera Roll/IMG_20211224_212327.jpg
# Image 2 selected: C:/Users/dfern/OneDrive/Pictures/Camera Roll/IMG_20211224_213212.jpg

# %%
from tkinter import *
from tkinter import filedialog
from PIL import Image, ImageTk
from tkinter import Menu, ttk
from ttkthemes import ThemedStyle

def on_button_click(button_number):
    if button_number in (1, 2):
        file_path = filedialog.askopenfilename(title="Select Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
        if file_path:
            # Load the selected image
            selected_image = Image.open(file_path)
            selected_image = selected_image.resize((200, 200), Image.ANTIALIAS)
            selected_photo = ImageTk.PhotoImage(selected_image)

            # Update the corresponding image in the top panel
            if button_number == 1:
                label_image1.config(image=selected_photo)
                label_image1.image = selected_photo
                print(f"Image 1 selected: {file_path}")
            elif button_number == 2:
                label_image2.config(image=selected_photo)
                label_image2.image = selected_photo
                print(f"Image 2 selected: {file_path}")

    elif button_number == 3:
        # Clear all images
        label_image1.config(image=None)
        label_image2.config(image=None)
        label_image1.image = None
        label_image2.image = None
        print("Images cleared")
        
    elif button_number == 4:
        # Exit the program
        root.destroy()

root = Tk()
root.title("Image Comparison")
root.geometry("900x650")

# Panels
panel_1 = PanedWindow(bd=4, relief='raised', bg='lightblue')
panel_1.pack(fill=BOTH, expand=1)

# Create a frame to hold buttons and labels in panel_1
button_frame = Frame(panel_1, bg='lightblue')

# Adding buttons to the left panel
button1 = Button(button_frame, text="Select Image 1", command=lambda: on_button_click(1), width=15, height=3)
button1.pack(fill=X, pady=5)

button2 = Button(button_frame, text="Select Image 2", command=lambda: on_button_click(2), width=15, height=3)
button2.pack(fill=X, pady=5)

button3 = Button(button_frame, text="Clear", command=lambda: on_button_click(3), width=15, height=3)
button3.pack(fill=X, pady=5)

button4 = Button(button_frame, text="Exit", command=lambda: on_button_click(4), width=15, height=3)
button4.pack(fill=X, pady=5)

left_label = Label(button_frame, text="Left Panel")
left_label.pack()

# Create a frame for image display
image_display_frame = Frame(root)
image_display_frame.pack(side=TOP)

# Create label_image1 and label_image2 before using them
label_image1 = Label(image_display_frame, text="Image 1 Display")
label_image1.pack(side=LEFT)

label_image2 = Label(image_display_frame, text="Image 2 Display")
label_image2.pack(side=LEFT)

# Add the button_frame to panel_1
panel_1.add(button_frame, minsize=200)

# Create second panel
panel_2 = PanedWindow(panel_1, orient=VERTICAL, bd=4, relief="raised", bg='red')
panel_1.add(panel_2, minsize=200)

bottom = Label(panel_2, text="Bottom Panel")
panel_2.add(bottom, minsize=100)


def on_menu_click(menu_item):
    if menu_item == "Open":
        on_button_click(1)  # Call the function for opening an image (Button 1)
    elif menu_item == "Process":
        on_button_click(2)  # Call the function for processing an image (Button 2)
    elif menu_item == "Clear":
        on_button_click(3)  # Call the function for clearing images (Button 3)
    elif menu_item == "Exit":
        on_button_click(4)  # Call the function for exiting the program (Button 4)
# Create the main menu bar
menu_bar = Menu(root)

# Apply a themed style to the menu bar
style = ThemedStyle(root)
style.set_theme("equilux")  # You can choose a different theme here


# Create a File menu
file_menu = Menu(menu_bar, tearoff=0, style="TMenu")
file_menu.add_command(label="Open", command=lambda: on_menu_click("Open"))
file_menu.add_command(label="Process", command=lambda: on_menu_click("Process"))
file_menu.add_command(label="Clear", command=lambda: on_menu_click("Clear"))
file_menu.add_separator()
file_menu.add_command(label="Exit", command=lambda: on_menu_click("Exit"))

# Add the File menu to the menu bar
menu_bar.add_cascade(label="File", menu=file_menu)

# Set the menu bar for the root window
root.config(menu=menu_bar)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3604/2949566610.py in <module>
#     103
#     104 # Create a File menu
# --> 105 file_menu = Menu(menu_bar, tearoff=0, style="TMenu")
#     106 file_menu.add_command(label="Open", command=lambda: on_menu_click("Open"))
#     107 file_menu.add_command(label="Process", command=lambda: on_menu_click("Process"))
#
# ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    3304         disabledforeground, fg, font, foreground, postcommand, relief,
#    3305         selectcolor, takefocus, tearoff, tearoffcommand, title, type."""
# -> 3306         Widget.__init__(self, master, 'menu', cnf, kw)
#    3307
#    3308     def tk_popup(self, x, y, entry=""):
#
# ...

# %%
pip install ttkthemes
# Out:
# ...
#      -------------------------------------- 891.2/891.2 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ttkthemes: filename=ttkthemes-3.2.2-cp310-cp310-win_amd64.whl size=1963896 sha256=a73929c0a75703378c83af0dbf91566e56bb92acd0f02c4de87c082eea1221cb
#   Stored in directory: c:\users\dfern\appdata\local\pip\cache\wheels\7f\18\83\c585dce55bb4eba21f2b74040e3d37b846e5d78fe99fb5e9cf
# Successfully built ttkthemes
# ...
# Note: you may need to restart the kernel to use updated packages.
