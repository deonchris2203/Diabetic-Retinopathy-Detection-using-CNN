# %%
import os
import cv2
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import save_model
from PIL import Image

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the paths to your train and test directories
train_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train'
test_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/test'

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 32

# Create an ImageDataGenerator for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,          # Rescale pixel values to the range [0, 1]
    validation_split=0.2,    # Specify the validation split
)

# Create a training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',      # For integer labels
    subset='training',        # Specify training subset
    seed=42                   # Set a random seed for reproducibility
)

# Create a validation data generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',      # Specify validation subset
    seed=42
)

# Create an ImageDataGenerator for testing data (without data augmentation)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create a testing data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=False  # Keep the order of images to match with predictions
)
# Out:
# Found 27834 images belonging to 5 classes.
# Found 6958 images belonging to 5 classes.
# Found 4971 images belonging to 5 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the path to your train directory
train_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train'

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 32

# Create an ImageDataGenerator for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,          # Rescale pixel values to the range [0, 1]
    validation_split=0.2,    # Specify the validation split
)

# Create a training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',      # For integer labels
    subset='training',        # Specify the training subset
    seed=42                   # Set a random seed for reproducibility
)

# Create a validation data generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',      # Specify the validation subset
    seed=42
)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])


# Train the model
model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 27834 images belonging to 5 classes.
# Found 6958 images belonging to 5 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11192/1684394662.py in <module>
#      45     Flatten(),
#      46     Dense(128, activation='relu'),
# ---> 47     Dense(num_classes, activation='softmax')
#      48 ])
#      49
#
# NameError: name 'num_classes' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the path to your train directory
train_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train'

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 32
num_classes = 5  # Adjust based on the number of classes in your dataset

# Create an ImageDataGenerator for training data
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
)

# Create a training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',  # For integer labels
    subset='training',
    seed=42
)

# Create a validation data generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',
    seed=42
)

# Define your model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile your model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train your model
history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 27834 images belonging to 5 classes.
# Found 6958 images belonging to 5 classes.
# Epoch 1/10
#   9/870 [..............................] - ETA: 45:47 - loss: 3.7132 - accuracy: 0.2292
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11192/1303182460.py in <module>
#      56
#      57 # Train your model
# ---> 58 history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# ~\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the paths to your train and test directories
train_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train'
test_dir = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/test'

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 32
num_classes = 5  # Adjust based on the number of classes in your dataset

# Create an ImageDataGenerator for training data
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
)

# Create a training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',  # For integer labels
    subset='training',
    seed=42
)

# Create a validation data generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',
    seed=42
)

# Create an ImageDataGenerator for testing data
test_datagen = ImageDataGenerator(rescale=1./255)

# Create a testing data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='sparse',
    shuffle=False  # Keep the order of images to match with predictions
)

# Define your model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile your model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Found 27834 images belonging to 5 classes.
# Found 6958 images belonging to 5 classes.
# Found 4971 images belonging to 5 classes.

# %%
# Train your model
history = model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Evaluate the model on the test dataset
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')

# %%
import os
import pandas as pd

# Specify the directory path
directory_path = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/4'

# Get a list of all files in the directory
file_list = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

# Create a DataFrame with the file names
df = pd.DataFrame({'File Names': file_list})

# Specify the output Excel file path
output_excel_path = 'D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train/file4.xlsx'

# Write the DataFrame to an Excel file
df.to_excel(output_excel_path, index=False)

print(f"File names have been saved to {output_excel_path}")
# Out:
# File names have been saved to D:/School/Btech Project/Data2/content/Diabetic_Balanced_Data/train/file4.xlsx
